# %% [markdown]
# 租房信息已经有了，为了能对北京目前的租房市场有个直观认识，我对数据进行深度分析，并进行可视化展示

# %% [markdown]
# 从分析结果中，我得到了哪些位置房源多、各区租房平均价格以及心仪价格地理位置分布等重要信息，为帮助我租房提供重要依据

# %% [markdown]
# 下面带大家一起看一下整个分析过程

# %%
import pandas as pd

# %%
df=pd.read_csv(r'/Users/lawrencezhang/Desktop/housing price map/housing info with geology coordinates.csv',encoding='gbk')
df.head(20)

# %%
path=r'/Users/lawrencezhang/Desktop/housing info with geology coordinates.xlsx'
df.to_excel(path,encoding='utf-8_sig')

# %% [markdown]
# ### 1.分析各行政区房源数量及单价

# %%
import sys
# !{sys.executable} -m pip install pyecharts
# Out:
# Collecting pyecharts
#   Using cached https://files.pythonhosted.org/packages/d2/1a/a094c0d11c3c87cf407cbd9dc069882e9bba08374df1ad81dfb39de1a8d3/pyecharts-1.9.0-py3-none-any.whl
# Collecting simplejson (from pyecharts)
#   Downloading https://files.pythonhosted.org/packages/15/8f/c59a6a253eb28e4cef2d7ea972caf6f6c8f65a10585187faab4c1af333e9/simplejson-3.17.2-cp37-cp37m-macosx_10_14_x86_64.whl (73kB)
#      |████████████████████████████████| 81kB 3.1kB/s eta 0:00:01
# Collecting prettytable (from pyecharts)
#   Using cached https://files.pythonhosted.org/packages/26/1b/42b59a4038bc0442e3a0085bc0de385658131eef8a88946333f870559b09/prettytable-2.1.0-py3-none-any.whl
# Requirement already satisfied: jinja2 in /Users/lawrencezhang/opt/anaconda3/lib/python3.7/site-packages (from pyecharts) (2.10.3)
# Requirement already satisfied: wcwidth in /Users/lawrencezhang/opt/anaconda3/lib/python3.7/site-packages (from prettytable->pyecharts) (0.1.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/lawrencezhang/opt/anaconda3/lib/python3.7/site-packages (from prettytable->pyecharts) (0.23)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/lawrencezhang/opt/anaconda3/lib/python3.7/site-packages (from jinja2->pyecharts) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/lawrencezhang/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->prettytable->pyecharts) (0.6.0)
# Requirement already satisfied: more-itertools in /Users/lawrencezhang/opt/anaconda3/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->prettytable->pyecharts) (7.2.0)
# Installing collected packages: simplejson, prettytable, pyecharts
# Successfully installed prettytable-2.1.0 pyecharts-1.9.0 simplejson-3.17.2

# %%
import pandas as pd
beijing_daname=['朝阳区', '丰台区', '海淀区', '大兴区', '通州区', '昌平区', '东城区', '西城区', '顺义区']
#data=pd.read_csv('租房数据加经纬度.csv',encoding='gbk')
data=pd.read_excel(r'/Users/lawrencezhang/Desktop/租房数据加经纬度.xlsx')
areas=list(set(list(data['行政区'])))
area_sums={}
for area in areas:
    area_sums[area]=list(data['行政区']).count(area)
from pyecharts import options as opts
from pyecharts.charts import Bar
import random
hotel_num=[area_sums[i] for i in beijing_daname]
bar = (
    Bar()
    .add_xaxis(beijing_daname)
    .add_yaxis("", hotel_num)
    .set_global_opts(title_opts=opts.TitleOpts(title="北京各区房源数量"))
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True),
        markline_opts=opts.MarkLineOpts(
            data=[
                opts.MarkLineItem(type_="min", name="最小值"),
                opts.MarkLineItem(type_="max", name="最大值"),
                opts.MarkLineItem(type_="average", name="平均值"),
            ]
        ),
    )
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cbd83cc134fa49f68040c9a69ee758c8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cbd83cc134fa49f68040c9a69ee758c8 = echarts.init(
#                     document.getElementById('cbd83cc134fa49f68040c9a69ee758c8'), 'white', {renderer: 'canvas'});
#                 var option_cbd83cc134fa49f68040c9a69ee758c8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 1877,
#                 836,
#                 645,
#                 463,
#                 457,
#                 349,
#                 318,
#                 283,
#                 272
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u671d\u9633\u533a",
#                 "\u4e30\u53f0\u533a",
#                 "\u6d77\u6dc0\u533a",
#                 "\u5927\u5174\u533a",
#                 "\u901a\u5dde\u533a",
#                 "\u660c\u5e73\u533a",
#                 "\u4e1c\u57ce\u533a",
#                 "\u897f\u57ce\u533a",
#                 "\u987a\u4e49\u533a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5404\u533a\u623f\u6e90\u6570\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_cbd83cc134fa49f68040c9a69ee758c8.setOption(option_cbd83cc134fa49f68040c9a69ee758c8);
#         });
#     </script>

# %% [markdown]
# 从上图可以得出以下结论：

# %% [markdown]
# 朝阳区的房源数量最多，有1877套
# 顺义区的房源数量最少，有272套
# 9个区平均房源数量为611套。

# %% [markdown]
# 各城区房源单价情况（每平米单价*30平米为例）

# %%
unit_price={}
for i in list(data.groupby('行政区')):
    if i[0] in beijing_daname:
        unit_price[i[0]]=int(i[1]['价格'].sum()/i[1]['面积'].sum())*30
unit_price
bar = (
    Bar()
    .add_xaxis(list(unit_price.keys()))
    .add_yaxis("", [unit_price[i] for i in list(unit_price.keys())])
    .set_global_opts(title_opts=opts.TitleOpts(title="北京各区租房均价（每平米单价*30平米为例）"))
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=True),
        markline_opts=opts.MarkLineOpts(
            data=[
                opts.MarkLineItem(type_="min", name="最小值"),
                opts.MarkLineItem(type_="max", name="最大值"),
                opts.MarkLineItem(type_="average", name="平均值"),
            ]
        ),
    )
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6c6776db821c46fb8e4d87b48992a4a8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6c6776db821c46fb8e4d87b48992a4a8 = echarts.init(
#                     document.getElementById('6c6776db821c46fb8e4d87b48992a4a8'), 'white', {renderer: 'canvas'});
#                 var option_6c6776db821c46fb8e4d87b48992a4a8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 4050,
#                 2610,
#                 1980,
#                 2070,
#                 3300,
#                 3030,
#                 4350,
#                 1620,
#                 1830
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e1c\u57ce\u533a",
#                 "\u4e30\u53f0\u533a",
#                 "\u5927\u5174\u533a",
#                 "\u660c\u5e73\u533a",
#                 "\u671d\u9633\u533a",
#                 "\u6d77\u6dc0\u533a",
#                 "\u897f\u57ce\u533a",
#                 "\u901a\u5dde\u533a",
#                 "\u987a\u4e49\u533a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5404\u533a\u79df\u623f\u5747\u4ef7\uff08\u6bcf\u5e73\u7c73\u5355\u4ef7*30\u5e73\u7c73\u4e3a\u4f8b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6c6776db821c46fb8e4d87b48992a4a8.setOption(option_6c6776db821c46fb8e4d87b48992a4a8);
#         });
#     </script>

# %% [markdown]
# 以30平米为例：
# 西城区的住房价格最高，为4350元
# 通州区的租房价格最低，为1620元
# 价格差距还是很大的。

# %% [markdown]
# ### 2.分析分析各户型占比及价格分布

# %%
layouts=list(set(data['户型']))
layout=data.loc[:,'户型'].value_counts()
from pyecharts import options as opts
from pyecharts.charts import Pie
print(list(layout.index)[:10])
values=[int(i) for i in list(layout.values)[:10]]
pie = (
    Pie()
   .add(
        "",
        [(i,j)for i,j in zip(list(layout.index)[:10],values)],
        radius=["30%", "75%"],
        center=["40%", "50%"],
        rosetype="radius",
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="北京市各区出租房户型占比"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="85%", orient="vertical"),)
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c},{d}%"))
)
pie.render_notebook()
# Out:
# ['1室1厅1卫', '2室1厅1卫', '1室0厅1卫', '3室2厅2卫', '2室2厅1卫', '3室1厅1卫', '2室2厅2卫', '2室1厅2卫', '3室1厅2卫', '1室2厅2卫']
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1c8bd9071e9b412a8cbcca46d49de97f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1c8bd9071e9b412a8cbcca46d49de97f = echarts.init(
#                     document.getElementById('1c8bd9071e9b412a8cbcca46d49de97f'), 'white', {renderer: 'canvas'});
#                 var option_1c8bd9071e9b412a8cbcca46d49de97f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "1\u5ba41\u53851\u536b",
#                     "value": 2324
#                 },
#                 {
#                     "name": "2\u5ba41\u53851\u536b",
#                     "value": 1718
#                 },
#                 {
#                     "name": "1\u5ba40\u53851\u536b",
#                     "value": 619
#                 },
#                 {
#                     "name": "3\u5ba42\u53852\u536b",
#                     "value": 240
#                 },
#                 {
#                     "name": "2\u5ba42\u53851\u536b",
#                     "value": 193
#                 },
#                 {
#                     "name": "3\u5ba41\u53851\u536b",
#                     "value": 183
#                 },
#                 {
#                     "name": "2\u5ba42\u53852\u536b",
#                     "value": 117
#                 },
#                 {
#                     "name": "2\u5ba41\u53852\u536b",
#                     "value": 89
#                 },
#                 {
#                     "name": "3\u5ba41\u53852\u536b",
#                     "value": 69
#                 },
#                 {
#                     "name": "1\u5ba42\u53852\u536b",
#                     "value": 67
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c},{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1\u5ba41\u53851\u536b",
#                 "2\u5ba41\u53851\u536b",
#                 "1\u5ba40\u53851\u536b",
#                 "3\u5ba42\u53852\u536b",
#                 "2\u5ba42\u53851\u536b",
#                 "3\u5ba41\u53851\u536b",
#                 "2\u5ba42\u53852\u536b",
#                 "2\u5ba41\u53852\u536b",
#                 "3\u5ba41\u53852\u536b",
#                 "1\u5ba42\u53852\u536b"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "85%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5e02\u5404\u533a\u51fa\u79df\u623f\u6237\u578b\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1c8bd9071e9b412a8cbcca46d49de97f.setOption(option_1c8bd9071e9b412a8cbcca46d49de97f);
#         });
#     </script>

# %% [markdown]
# 由于户型种类比较多，所以我只选了前10种，从图中可以看出，房源主流是1室1厅1卫，占比41.86%,其次分别是是2室1厅1卫、1室0厅1卫，各占比30.58%和11.02%

# %%
cut_n=list(range(0,12000,1000))
income=pd.cut(data["价格"],cut_n)
price_cut=data['价格'].groupby(income).count()
index=list(price_cut.index)
index=[str(i) for i in list(price_cut.index)]
values=[int(i) for i in list(price_cut.values)]
pie = (
    Pie()
   .add(
        "",
        [(i,j)for i,j in zip(index,values)],
        radius=["30%", "75%"],
        center=["40%", "50%"],
        rosetype="radius",
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="北京市各区出租房户型占比"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="85%", orient="vertical"),)
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}:  {c}, {d}%"))
)
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0d6eca1d9d38466f88fd47093ddfdeaa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0d6eca1d9d38466f88fd47093ddfdeaa = echarts.init(
#                     document.getElementById('0d6eca1d9d38466f88fd47093ddfdeaa'), 'white', {renderer: 'canvas'});
#                 var option_0d6eca1d9d38466f88fd47093ddfdeaa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "(0, 1000]",
#                     "value": 85
#                 },
#                 {
#                     "name": "(1000, 2000]",
#                     "value": 295
#                 },
#                 {
#                     "name": "(2000, 3000]",
#                     "value": 718
#                 },
#                 {
#                     "name": "(3000, 4000]",
#                     "value": 941
#                 },
#                 {
#                     "name": "(4000, 5000]",
#                     "value": 889
#                 },
#                 {
#                     "name": "(5000, 6000]",
#                     "value": 865
#                 },
#                 {
#                     "name": "(6000, 7000]",
#                     "value": 674
#                 },
#                 {
#                     "name": "(7000, 8000]",
#                     "value": 447
#                 },
#                 {
#                     "name": "(8000, 9000]",
#                     "value": 257
#                 },
#                 {
#                     "name": "(9000, 10000]",
#                     "value": 147
#                 },
#                 {
#                     "name": "(10000, 11000]",
#                     "value": 77
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}:  {c}, {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "(0, 1000]",
#                 "(1000, 2000]",
#                 "(2000, 3000]",
#                 "(3000, 4000]",
#                 "(4000, 5000]",
#                 "(5000, 6000]",
#                 "(6000, 7000]",
#                 "(7000, 8000]",
#                 "(8000, 9000]",
#                 "(9000, 10000]",
#                 "(10000, 11000]"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "85%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5e02\u5404\u533a\u51fa\u79df\u623f\u6237\u578b\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_0d6eca1d9d38466f88fd47093ddfdeaa.setOption(option_0d6eca1d9d38466f88fd47093ddfdeaa);
#         });
#     </script>

# %% [markdown]
# 目前，主流的租房价格在3000至6000元，占比50%左右，最便宜有1000元以下的,位置相对较偏，且面积在20平以内；贵的有1万多的,这种一般面积在100平以上，位置在主城区

# %% [markdown]
# ### 3.房子位置分布

# %% [markdown]
# 根据上述分析情况和我的预算，我决定在朝阳区找一套合适的房子，取出价格在4000至6000元的数据，另存表格，并将表格导入水经注地图下载器中

# %%
com_data=data[data['价格'].le(6000)]
com_data=com_data[com_data['价格'].ge(4000)]
com_data=com_data[com_data['行政区']=='朝阳区']
com_data.to_excel('心仪房子.xlsx',encoding='gbk')
#com_data.to_csv('心仪房子.csv',encoding='gbk')

# %%
com_data
# Out:
#       Unnamed: 0  Unnamed: 0.1                            摘要      户型      面积  \
# 42            42            42  望京SOHO大山子餼鸺鑶金盏嘉园精装一居家电齐全随时入住  1室1厅1卫   65.00
# 93            93            93                    朝阳旺角龒室龒厅龒卫  1室1厅1卫  102.00
# 153          153           153                 高碑店村餼号院龒室驋厅龒卫  1室0厅1卫  260.00
# 178          178           178    齤餼平大两居半地下便宜出租装修好朝阳大悦城南閏驋驋m  2室1厅1卫   35.06
# 224          224           224   潘家园十里河龤閏号线地铁周庄嘉园一居室随时看房拎包入住  1室1厅1卫   56.70
# ...          ...           ...                           ...     ...     ...
# 5912        5912          5912                整租|乐乎社区十里河美联居店  1室1厅1卫   30.00
# 5915        5915          5915               整租|乐乎社区垡头五方桥旗舰店  1室1厅1卫   30.00
# 5916        5916          5916                 整租|乐乎社区垡头五方桥A  1室1厅1卫   30.00
# 5920        5920          5920              整租|乐乎社区双桥品牌公寓双桥店  1室1厅1卫   18.00
# 5921        5921          5921                整租|乐乎社区十里河美联居店  1室1厅1卫   30.00
#
#                                       位置    价格          经度         纬度  行政区
# 42                             大山子金盏嘉园C区  3900  116.554461  40.009110  朝阳区
# 93                双桥朝阳旺角距八通线双桥地铁站步行1329m  4000  116.576760  39.910140  朝阳区
# 153           高碑店高碑店村5号院距八通线高碑店地铁站步行604m  2400  116.576760  39.910140  朝阳区
# 178   甘露园甘露园南里二社区(甘露园...距6号线青年路地铁站步行914m  4000  116.515838  39.918126  朝阳区
# 224    十里河周庄嘉园7号院距14号线(东)北工大西门地铁站步行1500m  4000  116.477682  39.862922  朝阳区
# ...                                  ...   ...         ...        ...  ...
# 5912                          十里河  新农创大厦  3400  116.459088  39.861674  朝阳区
# 5915                       垡头  马房寺路398号楼  2300  116.539418  39.868235  朝阳区
# 5916                          垡头  398科创园  2299  116.535040  39.867700  朝阳区
# 5920                          双桥  东星时尚广场  2480  116.574229  39.907854  朝阳区
# 5921                          十里河  新农创大厦  3400  116.459088  39.861674  朝阳区
#
# [351 rows x 10 columns]

# %% [markdown]
# 结果展示如下:

# %% [markdown]
# 下面红色数字为租房价格，这样找起来就更方便了
